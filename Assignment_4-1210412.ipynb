# %% [markdown]
# # Hi there 👋
# ---
# ## This is my fourth assignment in <span style="color: blue"> COMP4381</span>.
# ## My name is :<span style="color: #F41F4E"> Worood Assi.</span>
# ## & my ID is:<span style="color: #F41F4E"> 1210412.</span>
# ***

# %% [markdown]
# In this assignment, I will navigate Kaggle to select the <span style="color: brown; font-size: 20px">Titanic Data Set</span>. The Titanic dataset offers a comprehensive glimpse into the passengers aboard the ill-fated RMS Titanic, which famously sank on its maiden voyage in April 1912 after colliding with an iceberg. This dataset contains a wealth of information about individual passengers, including demographics, ticket class, cabin information, family relationships, fare details, and most notably, survival outcomes.
#
# - you can get it using: https://www.kaggle.com/datasets/zain280/titanic-data-set?resource=download

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

# %% [markdown]
# ### <span style="font-width: bold">Describe the data set and show the dictionary of the columns (for each column provide the name, data type, and description):</span>
#
# As shown below

# %%
# Read data from csv file
df = pd.read_csv('train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %% [markdown]
# ### Dataset Description
#
# - **Passenger Class (Pclass):** This categorical variable indicates the ticket class of each passenger, ranging from 1st class (wealthiest) to 3rd class (lower socioeconomic status).
#
# - **Name:** The names of passengers, providing insight into their identities.
#
# - **Sex:** Gender of passengers, categorized as male or female.
#
# - **Age:** Age of passengers, providing information about the demographic composition of the Titanic's passengers.
#
# - **SibSp:** Number of siblings/spouses aboard the Titanic, offering insight into family relationships.
#
# - **Parch:** Number of parents/children aboard the Titanic, indicating family size and composition.
#
# - **Ticket:** Ticket number, providing additional information about passenger accommodations and fare details.
#
# - **Fare:** Fare paid by each passenger, which can be indicative of their ticket class and economic status.
#
# - **Cabin:** Cabin number or location, offering insights into passenger accommodations.
#
# - **Embarked:** Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton), providing information about passengers' embarkation points.
#
# - **Survived:** This binary variable indicates whether a passenger survived the disaster (1) or not (0), serving as the primary outcome variable for analyses.
# riable for analyses.riable for analyses.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### After loaded the data set from train.csv file, I answered the following questions:

# %% [markdown]
# - What is the shape of the data?
#     <blockquote>the shape of data is 891x12
# - Does it contain missing values?
#     <blockquote>yes, there are missing values, and the output shows the count of missing values for each column in the dataset.

# %%
print(f'The count of all missing values is = {df.isna().sum().sum()}')
df.isna().sum()
# Out:
# The count of all missing values is = 866
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Which features are numerical, and which are nominal, and which are ordinal ?
#     - Numerical features: Age, Fare, SibSp, Parch.
#     - Nominal features: PassengerId, Name, Sex, Ticket, Cabin, Embarked.
#     - Ordinal feature: Pclass.

# %% [markdown]
# - Select two numerical features and:
#     - Show their descriptive statistics, add your interpretation on each feature
#           <blockquote> I selected both the Fare and age to Show their descriptive statistics, the Age descriptive statistics reveal that there are 714 valid entries in the dataset(There are missing values ​​depending on the shape of the data). The average age among passengers is around 29.70 years, with a standard deviation of 14.53. The youngest passenger recorded is just 0.42 years old. On the contrary, the oldest passenger is 80.00 years old.In addition to this 25% from data are less than 20.125, 50% from data are less than 28, and 75% from data are less than 38.
#
#
#   <blockquote> and the Fare descriptive statistics show that the dataset comprises 891 entries. The average fare among passengers is around 32.20 units for their fare, with a standard deviation of 49.69. The minimum fare is 0.00, implying that some passengers either traveled for free or received complimentary tickets. The maximum fare recorded is 512.33.In addition to this 25% from data are less than 7091.4, 50% from data are less than 14.4542, and 75% from data are less than 31.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - Does they have skweness?
#
# A skewed distribution is a distribution that departs from symmetry in the sense that most of the cases are concentrated at one end of the distribution.
#
#     Both the Age and the Fare have positive skewness values, suggesting a right-skewed distribution. This skewness indicates that the data is stretched out towards higher values, with a longer tail on the right side of the distribution.

# %%
# Calculate skewness for Age and Fare
age_skewness = df['Age'].skew()
fare_skewness = df['Fare'].skew()

print("Skewness of Age:", age_skewness)
print("Skewness of Fare:", fare_skewness)
# Out:
# Skewness of Age: 0.38910778230082704
# Skewness of Fare: 4.787316519674893

# %% [markdown]
# - Select two categorical features and verify if the data is balanced between the categories of each feature
#
#     I selected both the Sex and Pclass to verify if the data is balanced or not:
# <blockquote> I calculated the count for each value within the categories of Sex and Pclass. Then, I verified if these values were numerical using the following equation:  <span style="font-weight:bold">min_value >= (0.5 * max_value)</span> if the result is true so the feature is balance.
#
# - The result was as follows:
#     - Sex feature is balanced
#     - Pclass feature is not balancede.

# %%
# Calculate count of each category
sex_counts = df['Sex'].value_counts()
pclass_counts = df['Pclass'].value_counts()

# Compare counts to check for balance
is_sex_balanced = sex_counts.min() >= 0.5 * sex_counts.max()
is_pclass_balanced = pclass_counts.min() >= 0.5 * pclass_counts.max()

print("Is Sex feature balanced?", is_sex_balanced)
print("Is Pclass feature balanced?", is_pclass_balanced)
# Out:
# Is Sex feature balanced? True
# Is Pclass feature balanced? False

# %% [markdown]
# #### This can be seen from the following illustration:

# %%
plot.figure(figsize=(10, 4))

plot.subplot(1, 2, 1)
plot.bar(sex_counts.index, sex_counts.values, color='#FFC1C3')
plot.title('Distribution of Sex')
plot.xlabel('Sex')
plot.ylabel('Count')

plot.subplot(1, 2, 2)
plot.bar(pclass_counts.index, pclass_counts.values, color='#D598CF')
plot.title('Distribution of Pclass')
plot.xlabel('Pclass')
plot.ylabel('Count')

plot.tight_layout()
plot.show()

# %% [markdown]
# - Based on your intuition, select two features that you think they could be correlated. Verify your assumption using both visualization and the correlation coefficient approaches
#     - From my point of view, there could be a relationship between the Age of the passenger and the Fare to board the Titanic, and I believe that there is a positive relationship between them. As a person’s age increases and he grows older, his life becomes more dangerous and he needs more health care. Therefore, the price of his ticket may be more than that of young people.

# %%
df.plot.scatter(x='Age', y='Fare');

# %%
df.corr()
# Out:
# <ipython-input-21-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %% [markdown]
# **by Verify my assumption using both visualization and the correlation coefficient approaches:** There is a weak direct relationship between the age of the passenger and the fare he pays. And the correlation coefficient between them is equal *0.096067*

# %% [markdown]
# - Are their features that can be used as index?
#     - Yes, thes is a PassengerId column can be used as index because it does not have duplicate values.

# %%
df['PassengerId'].duplicated().any()
# Out:
# False
